# %%
# !chmod +x sample_asl_video_level_original_notrestore.sh
# !./sample_asl_video_level_original_notrestore.sh
# Out:
# Creating gs://mrudula_yt8m_train_bucket/...
# ServiceException: 409 Bucket mrudula_yt8m_train_bucket already exists.
# ...

# %%
# !gcloud ml-engine jobs describe yt8m_train_20170803_015910
# Out:
# createTime: '2017-08-03T01:59:12Z'
# jobId: yt8m_train_20170803_015910
# state: PREPARING
# trainingInput:
#   args:
#   - --train_data_pattern=gs://isaacoutputfinal/train*
#   - --model=MoeModel
#   - --train_dir=gs://mrudula_yt8m_train_bucket/yt8m_train_20170803_015910
#   - --start_new_model
#   - '='
#   - 'True'
#   - /
#   masterType: complex_model_m_gpu
#   packageUris:
#   - gs://mrudula_yt8m_train_bucket/yt8m_train_20170803_015910/145196780241cc00d44d3aba4a273d5efb541c6ec7a59af61a6c4f144b0e4b55/youtube-8m-0.0.0.tar.gz
#   parameterServerCount: '1'
#   parameterServerType: standard
#   pythonModule: youtube-8m.train
#   region: us-east1
#   runtimeVersion: '1.0'
#   scaleTier: CUSTOM
#   workerCount: '2'
#   workerType: standard_gpu
# trainingOutput: {}
#
# View job in the Cloud Console at:
# https://console.cloud.google.com/ml/jobs/yt8m_train_20170803_015910?project=qwiklabs-gcp-3efe763afa31c340
#
# View logs at:
# ...

# %%
import google.datalab.ml as ml
tensorboard_pid = ml.TensorBoard.start("gs://mrudula_yt8m_train_bucket/yt8m_train_20170803_015910")
# Out:
# <p>TensorBoard was started successfully with pid 12153. Click <a href="/_proxy/50418/" target="_blank">here</a> to access it.</p>

# %%
# !gsutil ls gs://bose-asl-cohort
# Out:
# gs://bose-asl-cohort/yt8m_train_20170802_200323/
# gs://bose-asl-cohort/yt8m_train_20170802_200433/
# gs://bose-asl-cohort/yt8m_train_20170802_201755/
# gs://bose-asl-cohort/yt8m_train_20170802_202103/
# gs://bose-asl-cohort/yt8m_train_20170802_202149/
# gs://bose-asl-cohort/yt8m_train_20170802_202227/

# %%
# !chmod +x EVAL_asl_video_level.sh
# !./EVAL_asl_video_level.sh
# Out:
# Creating gs://mrudula_yt8m_train_bucket/...
# ServiceException: 409 Bucket mrudula_yt8m_train_bucket already exists.
# ...

# %%
# !gcloud ml-engine jobs describe yt8m_eval_20170803_024448
# Out:
# createTime: '2017-08-03T02:44:50Z'
# jobId: yt8m_eval_20170803_024448
# state: PREPARING
# trainingInput:
#   args:
#   - --eval_data_pattern=gs://youtube8m-ml-us-east1/1/video_level/validate/validate*.tfrecord
#   - --model=MoeModel
#   - --train_dir=gs://mrudula_yt8m_train_bucket/yt8m_train_20170803_015910
#   - --run_once=False
#   masterType: standard
#   packageUris:
#   - gs://mrudula_yt8m_train_bucket/yt8m_eval_20170803_024448/32aa4f0c4732511f9c3b7aaf3c5e411443db6f7d7add4b78d8f6cf317313ea75/youtube-8m-0.0.0.tar.gz
#   pythonModule: youtube-8m.eval
#   region: us-east1
#   runtimeVersion: '1.0'
#   scaleTier: CUSTOM
# trainingOutput: {}
#
# View job in the Cloud Console at:
# https://console.cloud.google.com/ml/jobs/yt8m_eval_20170803_024448?project=qwiklabs-gcp-3efe763afa31c340
#
# View logs at:
# https://console.cloud.google.com/logs?resource=ml.googleapis.com%2Fjob_id%2Fyt8m_eval_20170803_024448&project=qwiklabs-gcp-3efe763afa31c340

# %%
import google.datalab.ml as ml
tensorboard_pid = ml.TensorBoard.start("gs://mrudula_yt8m_train_bucket/yt8m_train_20170803_015910")
# Out:
# <p>TensorBoard was started successfully with pid 7505. Click <a href="/_proxy/53881/" target="_blank">here</a> to access it.</p>

# %%
# !gsutil ls gs://isaacoutputfinal
# Out:
# gs://isaacoutputfinal/train-00000-of-04096
# gs://isaacoutputfinal/train-00001-of-04096
# gs://isaacoutputfinal/train-00002-of-04096
# gs://isaacoutputfinal/train-00003-of-04096
# gs://isaacoutputfinal/train-00004-of-04096
# gs://isaacoutputfinal/train-00005-of-04096
# gs://isaacoutputfinal/train-00006-of-04096
# gs://isaacoutputfinal/train-00007-of-04096
# gs://isaacoutputfinal/train-00008-of-04096
# gs://isaacoutputfinal/train-00009-of-04096
# gs://isaacoutputfinal/train-00010-of-04096
# gs://isaacoutputfinal/train-00011-of-04096
# gs://isaacoutputfinal/train-00012-of-04096
# gs://isaacoutputfinal/train-00013-of-04096
# gs://isaacoutputfinal/train-00014-of-04096
# gs://isaacoutputfinal/train-00015-of-04096
# gs://isaacoutputfinal/train-00016-of-04096
# gs://isaacoutputfinal/train-00017-of-04096
# gs://isaacoutputfinal/train-00018-of-04096
# gs://isaacoutputfinal/train-00019-of-04096
# gs://isaacoutputfinal/train-00020-of-04096
# gs://isaacoutputfinal/train-00021-of-04096
# ...

# %%
# !gsutil cp -r gs://isaacoutputfinal/  gs://mrudula_yt8m_train_bucket/issacOutputFinal
# Out:
# Copying gs://isaacoutputfinal/train-00000-of-04096 [Content-Type=application/octet-stream]...
# AccessDeniedException: 403 Forbidden

# %%
# !chmod +x sample_asl_video_level_original.sh
# !./sample_asl_video_level_original.sh
# Out:
# Creating gs://mrudula_yt8m_train_bucket/...
# ServiceException: 409 Bucket mrudula_yt8m_train_bucket already exists.
# ...

# %%
# !gcloud ml-engine jobs describe yt8m_train_20170803_001433
# Out:
# createTime: '2017-08-03T00:14:34Z'
# jobId: yt8m_train_20170803_001433
# state: QUEUED
# trainingInput:
#   args:
#   - --train_data_pattern=gs://isaacoutputfinal/train-00001-of-04096
#   - --model=MoeModel
#   - --train_dir=gs://mrudula_yt8m_train_bucket/yt8m_train_20170802_232452
#   - --start_new_model
#   - '='
#   - 'False'
#   - /
#   masterType: standard_gpu
#   packageUris:
#   - gs://mrudula_yt8m_train_bucket/yt8m_train_20170803_001433/37309771a4a0510d03fdd130a9bc71714ae01db63c8cb5c3337f65438ed7c930/youtube-8m-0.0.0.tar.gz
#   pythonModule: youtube-8m.train
#   region: us-east1
#   runtimeVersion: '1.0'
#   scaleTier: CUSTOM
# trainingOutput: {}
#
# View job in the Cloud Console at:
# https://console.cloud.google.com/ml/jobs/yt8m_train_20170803_001433?project=qwiklabs-gcp-3efe763afa31c340
#
# View logs at:
# https://console.cloud.google.com/logs?resource=ml.googleapis.com%2Fjob_id%2Fyt8m_train_20170803_001433&project=qwiklabs-gcp-3efe763afa31c340

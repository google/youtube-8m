# %%
import logging
import psycopg2
from heapq import merge
from itertools import groupby
from operator import itemgetter

def fetch(dbname, user, host, password, query):
    connection_string = "dbname='{0}' user='{1}' host='{2}' password='{3}'".format(
        dbname, user, host, password)
    try:
        conn = psycopg2.connect(connection_string)
        curr = conn.cursor()
        curr.execute(query)
        res = curr.fetchall()
    except Exception as e:
        print(e)
        logging.exception('')
    finally:
        curr.close()
        conn.close()
        
    return res

def inner_join(a, b):
    '''
    Joins two iterables of tuples on the first 
    element
    
    Arguments:
    a - list of tuples (id, x)
    b - list of tuples (id, y)
    
    Returns:
    list of tuples (id, x, y)
    '''
    key = itemgetter(0)
    a.sort(key=key) 
    b.sort(key=key)
    for _, group in groupby(merge(a, b, key=key), key):
        row_a, row_b = next(group), next(group, None)
        if row_b is not None: # join
            yield row_a + row_b[1:]

# %% [markdown]
# ## Videos data

# %%
dbname='ds-wizards'
user='wizard'
host='192.95.32.117'
password='GaG23jVxZhMnQaU53r8o'

VQUERY = "select post_id, url from videos where status='ok'"

# %%
vres = fetch(dbname, user, host, password, VQUERY)
vres = [(post_id.split("_")[1], url) for post_id, url in vres]

# %% [markdown]
# ## Tags

# %%
dbname='ds-content-tags'
user='ds-content-tags'
password='0fXjWl592vNf1gYvIw8w'
host='192.95.32.117'

TQUERY = "select id, tags from videos where tags is not NULL"

# %%
tres = fetch(dbname, user, host, password, TQUERY)

# %% [markdown]
# ## Join videos with tags

# %%
import itertools
from collections import Counter

# %%
videos = inner_join(tres, vres)

# %%
# Filters top tags and creates mapping
count = Counter(itertools.chain(*[tup[1] for tup in res]))
tags_2_indices = { 
    video_id: index 
        for index, (video_id, count) in enumerate(count.most_common(), 1)
        if count >= 5 
}

# reverse index for decoding 
indices_2_tags = { 
    v: k for k, v in tags_2_indices.items()
}

def filter_videos_by_tags(videos, store, min_count = 5): 
    '''
    Creates generator with common tags
    '''
    for video_id, tags, url in videos:
        encoded = [tags_2_indices[t] for t in tags if t in store]
        if encoded:
            yield video_id, encoded, url

# %%
filtered_res = list(filter_videos_by_tags(videos, tags_2_indices, 10))

# %%
from t1000.embedding import video

# %%
video_path = 'https://ovh-object-storage-proxy.staging.nowthis.network/videos/341163402640457_1000200393447969.mp4'

# %%
frames = video.extract_frames(video_path)
# Out:
# CPU times: user 56 ms, sys: 104 ms, total: 160 ms
# Wall time: 1.01 s

# %%
import urllib.request
import os

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(frames[0])
